# %% [markdown]
# ### Anamoly detection using Isolation forest

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# %%
df=pd.read_csv("thyroid_dataset.csv")

# %%
df
# Out:
#        Age  Sex  on_thyroxine  ...  T4U_measured  FTI_measured  Outlier_label
# 0     0.45    1             0  ...          87.0          26.0              o
# 1     0.61    0             0  ...          96.0          64.0              o
# 2     0.16    0             1  ...         103.0          56.0              o
# 3     0.85    0             0  ...          61.0          39.0              o
# 4     0.75    1             0  ...         116.0           4.0              o
# ...    ...  ...           ...  ...           ...           ...            ...
# 6911  0.65    0             1  ...          75.0         204.0              n
# 6912  0.77    0             0  ...         107.0         117.0              n
# 6913  0.41    0             0  ...         114.0         109.0              n
# 6914  0.64    1             0  ...          88.0         121.0              n
# 6915  0.46    0             0  ...          91.0         102.0              n
#
# [6916 rows x 22 columns]

# %%
df.shape
# Out:
# (6916, 22)

# %%
X=df.drop(columns=['Outlier_label'],axis=1)

# %%
y=df['Outlier_label']

# %%
X.shape
# Out:
# (6916, 21)

# %%
scaler=StandardScaler()

# %%
X_scaled=scaler.fit_transform(X)

# %%
X_scaled
# Out:
# array([[-2.34449113e-02,  1.50050924e+00, -3.94405319e-01, ...,
#         -1.40951598e+00, -3.74590514e-02, -1.25859776e+00],
#        [ 2.40791602e-03, -6.66440415e-01, -3.94405319e-01, ...,
#         -6.57814578e-01,  2.27969782e-01, -5.68029663e-01],
#        [-7.03031607e-02, -6.66440415e-01,  2.53546276e+00, ...,
#         -7.17159426e-01,  4.34414431e-01, -7.13412420e-01],
#        ...,
#        [-2.99081181e-02, -6.66440415e-01, -3.94405319e-01, ...,
#          6.08208844e-01,  7.58827450e-01,  2.49748343e-01],
#        [ 7.25532113e-03,  1.50050924e+00, -3.94405319e-01, ...,
#          2.32358141e-01, -7.96695877e-03,  4.67822478e-01],
#        [-2.18291096e-02, -6.66440415e-01, -3.94405319e-01, ...,
#         -2.48028670e-02,  8.05093192e-02,  1.22538431e-01]],
#       shape=(6916, 21))

# %%
from sklearn.ensemble import IsolationForest

# %%
isof=IsolationForest(n_estimators=200,contamination="auto",random_state=42)

# %%
labels=isof.fit_predict(X_scaled)

# %%
labels
# Out:
# array([ 1,  1, -1, ...,  1,  1,  1], shape=(6916,))

# %%
from sklearn.decomposition import PCA

# %%
pca=PCA(n_components=2)

# %%
x_pca=pca.fit_transform(X_scaled)

# %%
plt.figure(figsize=(15,8))
plt.scatter(x_pca[:,0],x_pca[:,1])

# %%
plt.figure(figsize=(15,8))
plt.scatter(x_pca[:,0],x_pca[:,1],c=labels)

# %%
import numpy as np

n_outliers=np.sum(labels==-1)
n_normal=np.sum(labels==1)

# %%
print(n_outliers)
print(n_normal)
# Out:
# 270
# 6646

# %%
isof=IsolationForest(n_estimators=200,contamination="auto",random_state=42)
labels=isof.fit_predict(X_scaled)
x_pca=pca.fit_transform(X_scaled)
plt.figure(figsize=(15,8))
plt.scatter(x_pca[:,0],x_pca[:,1],c=labels)
n_outliers=np.sum(labels==-1)
n_normal=np.sum(labels==1)
print(n_outliers)
print(n_normal)
# Out:
# 270
# 6646
