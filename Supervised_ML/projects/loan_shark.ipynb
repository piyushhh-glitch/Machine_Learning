# %%
import numpy as np
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt 
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("loan_approval_data.csv")

# %%
df.head()
# Out:
#    Applicant_ID  Applicant_Income  Coapplicant_Income Employment_Status   Age  \
# 0           1.0           17795.0              1387.0          Salaried  51.0
# 1           2.0            2860.0              2679.0          Salaried  46.0
# 2           3.0            7390.0              2106.0          Salaried  25.0
# 3           4.0           13964.0              8173.0          Salaried  40.0
# 4           5.0           13284.0              4223.0     Self-employed  31.0
#
#   Marital_Status  Dependents  Credit_Score  Existing_Loans  DTI_Ratio  \
# 0        Married         0.0         637.0             4.0       0.53
# 1        Married         3.0         621.0             2.0       0.30
# 2         Single         2.0         674.0             4.0       0.20
# 3        Married         2.0         579.0             3.0       0.31
# 4         Single         2.0         721.0             1.0       0.29
#
#    Savings  Collateral_Value  Loan_Amount  Loan_Term Loan_Purpose  \
# ...

# %%
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Applicant_ID        950 non-null    float64
#  1   Applicant_Income    950 non-null    float64
#  2   Coapplicant_Income  950 non-null    float64
#  3   Employment_Status   950 non-null    object
#  4   Age                 950 non-null    float64
#  5   Marital_Status      950 non-null    object
#  6   Dependents          950 non-null    float64
#  7   Credit_Score        950 non-null    float64
#  8   Existing_Loans      950 non-null    float64
#  9   DTI_Ratio           950 non-null    float64
#  10  Savings             950 non-null    float64
#  11  Collateral_Value    950 non-null    float64
#  12  Loan_Amount         950 non-null    float64
#  13  Loan_Term           950 non-null    float64
#  14  Loan_Purpose        950 non-null    object
# ...

# %% [markdown]
# Handling missing values

# %%
categ_cols=df.select_dtypes(include=["object"]).columns
num_cols=df.select_dtypes(include=["float64"]).columns

# %%
categ_cols
# Out:
# Index(['Employment_Status', 'Marital_Status', 'Loan_Purpose', 'Property_Area',
#        'Education_Level', 'Gender', 'Employer_Category', 'Loan_Approved'],
#       dtype='object')

# %%
num_cols
# Out:
# Index(['Applicant_ID', 'Applicant_Income', 'Coapplicant_Income', 'Age',
#        'Dependents', 'Credit_Score', 'Existing_Loans', 'DTI_Ratio', 'Savings',
#        'Collateral_Value', 'Loan_Amount', 'Loan_Term'],
#       dtype='object')

# %%
categ_cols.size+num_cols.size
# Out:
# 20

# %%
from sklearn.impute import SimpleImputer
num_imp=SimpleImputer(strategy="mean")
df[num_cols]=num_imp.fit_transform(df[num_cols])

# %%
categ_imp=SimpleImputer(strategy="most_frequent")
df[categ_cols]=categ_imp.fit_transform(df[categ_cols])

# %%
df.sample()
# Out:
#      Applicant_ID  Applicant_Income  Coapplicant_Income Employment_Status  \
# 662         663.0           15013.0              7848.0          Salaried
#
#       Age Marital_Status  Dependents  Credit_Score  Existing_Loans  DTI_Ratio  \
# 662  37.0         Single         1.0         556.0             1.0       0.35
#
#      Savings  Collateral_Value  Loan_Amount  Loan_Term Loan_Purpose  \
# 662  16877.0           32009.0      38594.0       84.0         Home
#
#     Property_Area Education_Level Gender Employer_Category Loan_Approved
# 662     Semiurban        Graduate   Male          Business            No

# %%
df.isnull().sum()
# Out:
# Applicant_ID          0
# Applicant_Income      0
# Coapplicant_Income    0
# Employment_Status     0
# Age                   0
# Marital_Status        0
# Dependents            0
# Credit_Score          0
# Existing_Loans        0
# DTI_Ratio             0
# Savings               0
# Collateral_Value      0
# Loan_Amount           0
# Loan_Term             0
# Loan_Purpose          0
# Property_Area         0
# Education_Level       0
# Gender                0
# Employer_Category     0
# Loan_Approved         0
# dtype: int64

# %% [markdown]
# Exploratory Data Analysis-EDA

# %%
#Data distribution

classes_count=df["Loan_Approved"].value_counts()
plt.pie(classes_count,labels=["no","yes"],autopct="%1.1f%%")
plt.title("Is loan approved or not ?")
# Out:
# Text(0.5, 1.0, 'Is loan approved or not ?')

# %%
#Analyze categories

# gender_counts=df["Gender"].value_counts()
# ax=sns.barplot(gender_counts)
# ax.bar_label(ax.containers[0])

# edu_counts=df["Education_Level"].value_counts()
# ax=sns.barplot(edu_counts)
# ax.bar_label(ax.containers[0])


emp_counts=df["Employment_Status"].value_counts()
ax=sns.barplot(emp_counts)
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '515'), Text(0, 0, '213'), Text(0, 0, '182'), Text(0, 0, '90')]

# %%
#Lets analyze income

sns.histplot(
    data=df,
    x="Applicant_Income",
    bins=20
)
# Out:
# <Axes: xlabel='Applicant_Income', ylabel='Count'>

# %%
#applicant income

sns.histplot(
    data=df,
    x="Coapplicant_Income",
    bins=20
)
# Out:
# <Axes: xlabel='Coapplicant_Income', ylabel='Count'>

# %%
#Outliers detection -Boxplots

sns.boxplot(
    data=df,
    x="Loan_Approved",
    y="Applicant_Income"
)
# Out:
# <Axes: xlabel='Loan_Approved', ylabel='Applicant_Income'>

# %%
fig,axes=plt.subplots(2,3)

sns.boxplot(ax=axes[0,0],data=df,x="Loan_Approved",y="Applicant_Income")
sns.boxplot(ax=axes[0,1],data=df,x="Loan_Approved",y="Credit_Score")
sns.boxplot(ax=axes[0,2],data=df,x="Loan_Approved",y="DTI_Ratio")
sns.boxplot(ax=axes[1,0],data=df,x="Loan_Approved",y="Savings")
sns.boxplot(ax=axes[1,1],data=df,x="Loan_Approved",y="Loan_Amount")
sns.boxplot(ax=axes[1,2],data=df,x="Loan_Approved",y="Age")


plt.tight_layout()

# %%
#Loan approved vs Credit score

sns.histplot(
    data=df,
    x="Credit_Score",
    hue="Loan_Approved",
    bins=20,
    multiple="dodge"
)
# Out:
# <Axes: xlabel='Credit_Score', ylabel='Count'>

# %%
#Loan approved vs Applicant Income

sns.histplot(
    data=df,
    x="Applicant_Income",
    hue="Loan_Approved",
    bins=20,
    multiple="dodge"
)
# Out:
# <Axes: xlabel='Applicant_Income', ylabel='Count'>

# %%
#lets remove applicant id because it is not needed

df=df.drop(columns=["Applicant_ID"],axis=1)

# %%
df
# Out:
#      Applicant_Income  Coapplicant_Income Employment_Status   Age  \
# 0        17795.000000              1387.0          Salaried  51.0
# 1         2860.000000              2679.0          Salaried  46.0
# 2         7390.000000              2106.0          Salaried  25.0
# 3        13964.000000              8173.0          Salaried  40.0
# 4        13284.000000              4223.0     Self-employed  31.0
# ..                ...                 ...               ...   ...
# 995      10852.571579              9092.0          Salaried  58.0
# 996       3279.000000              6356.0     Self-employed  58.0
# 997      15192.000000              8433.0          Contract  48.0
# 998       9083.000000              7380.0        Unemployed  50.0
# 999      13093.000000              2385.0          Salaried  23.0
#
#     Marital_Status  Dependents  Credit_Score  Existing_Loans  DTI_Ratio  \
# 0          Married         0.0         637.0             4.0       0.53
# ...
